# %% [markdown]
# ## Text extraction

# %% [markdown]
# Let's webscraped some wikipedia sites having different languages and then cluster them ! We use here the three languages English, French and Spanish. Different stopwords lists are used, same for stemming, since there are 3 languages.

# %%
import wikipedia
import random
from random_words import RandomWords
import pandas as pd

rw = RandomWords()
lang = ['en','fr','es']

# %% [markdown]
# ###### Building a Data base like that

# %% [markdown]
# We first start with the wikipedia page with Phone numbers, since the tasks asks to get phone numbers. Sometimes, the random word chosen isn't on Wikipedia, so we have to raise exceptions.

# %%
Index = ['Telephone number']
Text = []
Language = ['en']

wikipedia.set_lang('en')
word = 'Telephone number'
Sentence = wikipedia.page(word).content.replace('\n', '')
Text.append(Sentence)

s = 0
while s<49:
    while True:
        language = random.choice(lang)
        wikipedia.set_lang(language)
        word = rw.random_word()
        try:
            Sentence = wikipedia.summary(word, sentences=4)
            Index.append(word)
            Text.append(Sentence)
            Language.append(language) 
            s+=1
            break
        except wikipedia.exceptions.DisambiguationError:
            pass
        except wikipedia.exceptions.PageError:
            pass
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\User\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
dic = {'Text': Text,
      'Language': Language,
      'Word' : Index}

df = pd.DataFrame.from_dict(dic)

# %%
df
# Out:
#    Language                                               Text  \
# 0        en  A telephone number is a sequence of digits ass...
# 1        fr  Le terme stencil, qui signifie « pochoir » en ...
# 2        fr  Une « capabilité » ou « capacité » ou « libert...
# 3        en  Diagnosis is the identification of the nature ...
# 4        en  The Savage Islands or Selvagens Islands (Portu...
# 5        fr  Le climat est la distribution statistique des ...
# 6        es  Progesterex es el nombre que fue dado a una dr...
# 7        fr  Feeling est le deuxième maxi-single de Leila s...
# 8        en  A mechanic is a tradesman, craftsman, or techn...
# 9        fr  L'official ou vicaire judiciaire est un juge e...
# 10       en  Interest is payment from a borrower or deposit...
# 11       es  Automatic Writing es el álbum debut de la band...
# 12       en  The 1950s (pronounced nineteen-fifties; common...
# 13       es  El Sol (S/)[2]​ (ISO 4217: PEN) es la unidad m...
# 14       es  Cork (irlandés: Corcaigh, derivado de corcach,...
# 15       en  A prime number (or a prime) is a natural numbe...
# 16       fr  L'amusie est une anomalie psychique dans laque...
# 17       en  Rain is liquid water in the form of droplets t...
# 18       en  October is the tenth month of the year in the ...
# 19       fr  Intellectual Property (alias Dark Mind - son n...
# 20       es  El río Platte, o río Chato[1]​ del original en...
# 21       es  n/a, escrito con letras minúsculas, es una abr...
# 22       en  Thought refers to ideas or arrangements of ide...
# 23       en  A semiconductor material has an electrical con...
# 24       es  Se denomina gas (palabra inventada por el cien...
# 25       fr  La médaille Fields est avec le prix Abel une d...
# 26       en  The sky (or celestial dome) is everything that...
# 27       en  Solder (,  or in North America ) is a fusible ...
# 28       fr  Tommy Pistol, né le 2 juillet 1976 dans le Que...
# 29       en  Volume is the quantity of three-dimensional sp...
# 30       en  A nest is a structure built by certain animals...
# 31       en  In physics a vapor (American) or vapour (Briti...
# 32       fr  The Last Ship ou Le Dernier Navire au Québec e...
# 33       en  Canals are human-made channels for water conve...
# 34       en  The mile is an English unit of length of linea...
# 35       es  Un mineral es una sustancia natural, de compos...
# 36       fr  Antony Charles Robert Armstrong-Jones, né le 7...
# 37       en  Quantity is a property that can exist as a mul...
# 38       en  There is no scholarly consensus over what prec...
# 39       es  Dunes es una población y comuna francesa, en l...
# 40       en  The chairman (also chairperson, chairwoman or ...
# 41       es  Las Escuelas Públicas de Highline (Highline Pu...
# 42       es  Meat es un personaje en la serie de juegos de ...
# 43       fr  Un registre Internet régional (RIR, de l'angla...
# 44       fr  L'Initiative sur l'Accessibilité du web ou Web...
# 45       fr  Le côt N est un cépage de cuve noir français. ...
# 46       es  El Sikorsky SH-60 / MH-60 Seahawk es un helicó...
# 47       es  Texas o Tejas[2]​ es uno de los cincuenta esta...
# 48       en  In physics, a wave is an oscillation accompani...
# 49       fr  Une magnéto d'allumage est une génératrice tra...
#
#                 Word
# 0   Telephone number
# 1           stencils
# 2       capabilities
# 3        diagnostics
# 4           salvages
# 5              cleat
# 6         sterilizer
# 7            feeling
# 8           mechanic
# 9           official
# 10          interest
# 11           writing
# 12           fifties
# 13             soles
# 14              cork
# 15            primes
# 16        amusements
# 17             rains
# 18          octobers
# 19          property
# 20           platter
# 21          acronyms
# 22           thought
# 23     semiconductor
# 24               gas
# 25            fields
# 26             skies
# 27           solders
# 28            pistol
# 29            volume
# 30             nests
# 31             vapor
# 32              ship
# 33            canals
# 34             miles
# 35          minerals
# 36        stationery
# 37          quantity
# 38          religion
# 39             dusts
# 40        chairwomen
# 41         highlines
# 42              meat
# 43     organizations
# 44        guidelines
# 45               cot
# 46             lamps
# 47             texts
# 48              wave
# 49          magnetos

# %% [markdown]
# ## Find phone numbers

# %%
import re

telephone_numbers = []

# %%
for i in range(len(df)):
    phone_numbers = re.findall('(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})',
                               df.loc[i,'Text'])
    telephone_numbers.append(phone_numbers)
    if phone_numbers:
        print("The phone numbers found on the wikipedia page '%s' :"%df.loc[i,'Word'])
        for w in phone_numbers:
            print(w)
            
df['Phone Numbers found'] = telephone_numbers
# Out:
# The phone numbers found on the wikipedia page 'Telephone number' :
# 555-1212
# 555-1212
# 776-2323
# 212-736-5000
# 867-5309

# %% [markdown]
# ## Determining the language

# %% [markdown]
# Using Google's language detection library

# %%
from langdetect import detect
lang_detect = []
Test = []

# %%
for i in range(len(df)):
    detected_language = detect(df.loc[i,'Text'])
    lang_detect.append(detected_language)
    test = detect(df.loc[i,'Text']) == df.loc[i,'Language']
    Test.append(test)
    print('Real Language : %s'%detected_language)
    print('Detected Languages : %s'%df.loc[i,'Language'])
    print('True if both languages are the same : %s' %test)
    print('\n')

df['Language detected'] = lang_detect
df['Same language ?'] = Test
# Out:
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : es
# Detected Languages : es
# True if both languages are the same : True
#
#
# Real Language : en
# Detected Languages : en
# True if both languages are the same : True
#
#
# Real Language : fr
# Detected Languages : fr
# True if both languages are the same : True

# %% [markdown]
# ## Part of speech tagging

# %%
from nltk.tag import pos_tag

proper_nouns = []

# %%
for i in range(len(df)):
    text = df.loc[i,'Text']
    tagged_sent = pos_tag(text.split(), lang=df.loc[i,'Language'])  
    propernouns = [word.replace("«",'').replace("»",'').replace('==','').replace('=','') for word,pos in tagged_sent if pos == 'NNP']
    print(*propernouns[:5], sep='\n')
    proper_nouns.append(propernouns)
    
df['Proper Nouns'] = [' '.join(liste) for liste in proper_nouns]
# Out:
# (PSTN)
# PSTN
# Lowell,
# Massachusetts,
# Concept
# Le
#
#
# En
# Selon
# Une
#
#
#
#
# Diagnosis
# Savage
# Selvagens
# Islands
# (Portuguese:
# Ilhas
# Le
# Il
# L'étude
# La
# Progesterex
# Internet
# Tagged,
# Facebook,
# Bebo,
# Leila
# Rephlex
# Records,
# Weather.
# Les
# Auto
# De
# Il
# être
# établi
# Le
#
# Automatic
# Writing
# álbum
# Ataxia,
# Record
# Fifties)
# Gregorian
# January
# December
# World
# El
# Sol
# (S/)[2]​
# PEN)
# Perú
# Cork
# (irlandés:
# Corcaigh,
# República
# Irlanda,
# A
# However,
# L'amusie
# L'amusie
# être
# L'amusie
# être
# Rain
# Earth.
# October
# Calendars
# Roman
# October
# Latin
# Intellectual
# Property
# (alias
# Dark
# Mind
# El
# Platte,
# Chato[1]​
# Platte
# River)?,
# La
# (/)
# Se
# (sin
# Véase
# Thought
# Thinking
# Their
# ("doping")
# Se
# (palabra
# Jan
# Baptista
# Helmont
# La
# médaille
# Fields
# Abel
# Elle
# (or
# Earth,
# Earth's
# Sun,
# Moon
# Solder
# North
# America
# Middle
# English
# Tommy
# Pistol,
# Queens
# à
# New
# SI
#
# A
# K
# (374
# Ship
# Le
# Dernier
# Navire
# Québec
#
# Roman
# Chinese
# England
# Un
# Es
# La
# El
# Antony
# Charles
# Robert
# Armstrong-Jones,
# à
# "more",
# "less",
# Quantity
# (as
# Religious
# Mediodía-Pirineos,
# Tarn
# Garona,
# Castelsarrasin
# y
# (also
# Las
# Escuelas
# Públicas
# Highline
# (Highline
# Mortal
# Kombat.
# El
# Lives"
# Ed
# Un
# Internet
# (RIR,
# Regional
# Internet
# Web
# Accessibility
# Initiative
# (WAI)
# World
# Le
# N
# Il
# N.
# C'est
# El
# Sikorsky
# SH-60
# /
# MH-60
# Texas
# Tejas[2]​
# Washington
# D.
# C.,
# Frequency
# Wave
# Une
# Elle
# André-Marie
# Ampère
# XIXe

# %%
df.tail()
# Out:
#    Language                                               Text      Word  \
# 45       fr  Le côt N est un cépage de cuve noir français. ...       cot
# 46       es  El Sikorsky SH-60 / MH-60 Seahawk es un helicó...     lamps
# 47       es  Texas o Tejas[2]​ es uno de los cincuenta esta...     texts
# 48       en  In physics, a wave is an oscillation accompani...      wave
# 49       fr  Une magnéto d'allumage est une génératrice tra...  magnetos
#
#    Phone Numbers found Language detected  Same language ?  \
# 45                  []                fr             True
# 46                  []                es             True
# 47                  []                es             True
# 48                  []                en             True
# 49                  []                fr             True
#
#                                          Proper Nouns
# 45  Le N Il N. C'est Cahors, Argentine Chili.  Ori...
# 46  El Sikorsky SH-60 / MH-60 Seahawk Sikorsky Air...
# 47  Texas Tejas[2]​ Washington D. C., Estados Unid...
# 48                                     Frequency Wave
# 49  Une Elle André-Marie Ampère XIXe électrique ét...

# %% [markdown]
# Careful for the French NNP !

# %% [markdown]
# ## Remove irrelevant words

# %%
from nltk.corpus import stopwords

stopwords_en = stopwords.words('english')
stopwords_fr = stopwords.words('french')
stopwords_es = stopwords.words('spanish')

Filtered = []

# %%
for i in range(len(df)):
    text = df.loc[i,'Text'] 
    filtered = [word.replace("«",'').replace("»",'').replace('==','') for word in text.split() if word.lower() not in globals()['stopwords_'+df.loc[i,'Language']]]
    Filtered.append(filtered)
    
df['Filtered'] = [' '.join(liste) for liste in Filtered]

# %%
df
# Out:
#    Language                                               Text  \
# 0        en  A telephone number is a sequence of digits ass...
# 1        fr  Le terme stencil, qui signifie « pochoir » en ...
# 2        fr  Une « capabilité » ou « capacité » ou « libert...
# 3        en  Diagnosis is the identification of the nature ...
# 4        en  The Savage Islands or Selvagens Islands (Portu...
# 5        fr  Le climat est la distribution statistique des ...
# 6        es  Progesterex es el nombre que fue dado a una dr...
# 7        fr  Feeling est le deuxième maxi-single de Leila s...
# 8        en  A mechanic is a tradesman, craftsman, or techn...
# 9        fr  L'official ou vicaire judiciaire est un juge e...
# 10       en  Interest is payment from a borrower or deposit...
# 11       es  Automatic Writing es el álbum debut de la band...
# 12       en  The 1950s (pronounced nineteen-fifties; common...
# 13       es  El Sol (S/)[2]​ (ISO 4217: PEN) es la unidad m...
# 14       es  Cork (irlandés: Corcaigh, derivado de corcach,...
# 15       en  A prime number (or a prime) is a natural numbe...
# 16       fr  L'amusie est une anomalie psychique dans laque...
# 17       en  Rain is liquid water in the form of droplets t...
# 18       en  October is the tenth month of the year in the ...
# 19       fr  Intellectual Property (alias Dark Mind - son n...
# 20       es  El río Platte, o río Chato[1]​ del original en...
# 21       es  n/a, escrito con letras minúsculas, es una abr...
# 22       en  Thought refers to ideas or arrangements of ide...
# 23       en  A semiconductor material has an electrical con...
# 24       es  Se denomina gas (palabra inventada por el cien...
# 25       fr  La médaille Fields est avec le prix Abel une d...
# 26       en  The sky (or celestial dome) is everything that...
# 27       en  Solder (,  or in North America ) is a fusible ...
# 28       fr  Tommy Pistol, né le 2 juillet 1976 dans le Que...
# 29       en  Volume is the quantity of three-dimensional sp...
# 30       en  A nest is a structure built by certain animals...
# 31       en  In physics a vapor (American) or vapour (Briti...
# 32       fr  The Last Ship ou Le Dernier Navire au Québec e...
# 33       en  Canals are human-made channels for water conve...
# 34       en  The mile is an English unit of length of linea...
# 35       es  Un mineral es una sustancia natural, de compos...
# 36       fr  Antony Charles Robert Armstrong-Jones, né le 7...
# 37       en  Quantity is a property that can exist as a mul...
# 38       en  There is no scholarly consensus over what prec...
# 39       es  Dunes es una población y comuna francesa, en l...
# 40       en  The chairman (also chairperson, chairwoman or ...
# 41       es  Las Escuelas Públicas de Highline (Highline Pu...
# 42       es  Meat es un personaje en la serie de juegos de ...
# 43       fr  Un registre Internet régional (RIR, de l'angla...
# 44       fr  L'Initiative sur l'Accessibilité du web ou Web...
# 45       fr  Le côt N est un cépage de cuve noir français. ...
# 46       es  El Sikorsky SH-60 / MH-60 Seahawk es un helicó...
# 47       es  Texas o Tejas[2]​ es uno de los cincuenta esta...
# 48       en  In physics, a wave is an oscillation accompani...
# 49       fr  Une magnéto d'allumage est une génératrice tra...
#
#                 Word                                Phone Numbers found  \
# 0   Telephone number  [555-1212, 555-1212, 776-2323, 212-736-5000, 8...
# 1           stencils                                                 []
# 2       capabilities                                                 []
# 3        diagnostics                                                 []
# 4           salvages                                                 []
# 5              cleat                                                 []
# 6         sterilizer                                                 []
# 7            feeling                                                 []
# 8           mechanic                                                 []
# 9           official                                                 []
# 10          interest                                                 []
# 11           writing                                                 []
# 12           fifties                                                 []
# 13             soles                                                 []
# 14              cork                                                 []
# 15            primes                                                 []
# 16        amusements                                                 []
# 17             rains                                                 []
# 18          octobers                                                 []
# 19          property                                                 []
# 20           platter                                                 []
# 21          acronyms                                                 []
# 22           thought                                                 []
# 23     semiconductor                                                 []
# 24               gas                                                 []
# 25            fields                                                 []
# 26             skies                                                 []
# 27           solders                                                 []
# 28            pistol                                                 []
# 29            volume                                                 []
# 30             nests                                                 []
# 31             vapor                                                 []
# 32              ship                                                 []
# 33            canals                                                 []
# 34             miles                                                 []
# 35          minerals                                                 []
# 36        stationery                                                 []
# 37          quantity                                                 []
# 38          religion                                                 []
# 39             dusts                                                 []
# 40        chairwomen                                                 []
# 41         highlines                                                 []
# 42              meat                                                 []
# 43     organizations                                                 []
# 44        guidelines                                                 []
# 45               cot                                                 []
# 46             lamps                                                 []
# 47             texts                                                 []
# 48              wave                                                 []
# 49          magnetos                                                 []
#
#    Language detected  Same language ?  \
# 0                 en             True
# 1                 fr             True
# 2                 fr             True
# 3                 en             True
# 4                 en             True
# 5                 fr             True
# 6                 es             True
# 7                 fr             True
# 8                 en             True
# 9                 fr             True
# 10                en             True
# 11                es             True
# 12                en             True
# 13                es             True
# 14                es             True
# 15                en             True
# 16                fr             True
# 17                en             True
# 18                en             True
# 19                fr             True
# 20                es             True
# 21                es             True
# 22                en             True
# 23                en             True
# 24                es             True
# 25                fr             True
# 26                en             True
# 27                en             True
# 28                en             True
# 29                en             True
# 30                en             True
# 31                en             True
# 32                fr             True
# 33                en             True
# 34                en             True
# 35                es             True
# 36                fr             True
# 37                en             True
# 38                en             True
# 39                es             True
# 40                en             True
# 41                es             True
# 42                es             True
# 43                fr             True
# 44                fr             True
# 45                fr             True
# 46                es             True
# 47                es             True
# 48                en             True
# 49                fr             True
#
#                                          Proper Nouns  \
# 0   (PSTN) PSTN Lowell, Massachusetts, Concept Whe...
# 1                                       Le   En Selon
# 2   Une       Amartya Sen, la L’approche Martha Nu...
# 3                                           Diagnosis
# 4   Savage Selvagens Islands (Portuguese: Ilhas Se...
# 5                                    Le Il L'étude La
# 6   Progesterex Internet Tagged, Facebook, Bebo, y...
# 7     Leila Rephlex Records, Weather. Les Il Feeling,
# 8                                                Auto
# 9                                De Il être établi Le
# 10
# 11  Automatic Writing álbum Ataxia, Record Collect...
# 12  Fifties) Gregorian January December World War ...
# 13  El Sol (S/)[2]​ PEN) Perú Esta Inti (I/.) Inic...
# 14  Cork (irlandés: Corcaigh, República Irlanda, M...
# 15                                         A However,
# 16          L'amusie L'amusie être L'amusie être à La
# 17                                        Rain Earth.
# 18  October Calendars Roman October Latin January ...
# 19  Intellectual Property (alias Dark Mind Nichola...
# 20  El Platte, Chato[1]​ Platte River)?, Medio Oes...
# 21  La (/) Se (sin Véase  Portal:Lingüística. Cont...
# 22                                   Thought Thinking
# 23                                   Their ("doping")
# 24  Se (palabra Jan Baptista Helmont XVII, Los Las...
# 25        La médaille Fields Abel Elle Nobel Elle Les
# 26                       (or Earth, Earth's Sun, Moon
# 27  Solder North America Middle English Old French...
# 28  Tommy Pistol, Queens à New York, Il Award  Mei...
# 29                                                 SI
# 30
# 31                                           A K (374
# 32  Ship Le Dernier Navire Québec Hank Steinberg S...
# 33
# 34                              Roman Chinese England
# 35                                        Un Es La El
# 36  Antony Charles Robert Armstrong-Jones, à Londr...
# 37                       "more", "less", Quantity (as
# 38                                          Religious
# 39  Mediodía-Pirineos, Tarn Garona, Castelsarrasin...
# 40                                              (also
# 41  Las Escuelas Públicas Highline (Highline Publi...
# 42  Mortal Kombat. El Lives" Ed Boon Mortal Kombat...
# 43  Un Internet (RIR, Regional Internet Registry) ...
# 44  Web Accessibility Initiative (WAI) World Wide ...
# 45  Le N Il N. C'est Cahors, Argentine Chili.  Ori...
# 46  El Sikorsky SH-60 / MH-60 Seahawk Sikorsky Air...
# 47  Texas Tejas[2]​ Washington D. C., Estados Unid...
# 48                                     Frequency Wave
# 49  Une Elle André-Marie Ampère XIXe électrique ét...
#
#                                              Filtered
# 0   telephone number sequence digits assigned fixe...
# 1   terme stencil, signifie  pochoir  anglais, pre...
# 2    capabilité   capacité   liberté substantielle...
# 3   Diagnosis identification nature cause certain ...
# 4   Savage Islands Selvagens Islands (Portuguese: ...
# 5   climat distribution statistique conditions l'a...
# 6   Progesterex nombre dado droga inexistente menc...
# 7   Feeling deuxième maxi-single Leila sorti 1998 ...
# 8   mechanic tradesman, craftsman, technician uses...
# 9   L'official vicaire judiciaire juge ecclésiasti...
# 10  Interest payment borrower deposit-taking finan...
# 11  Automatic Writing álbum debut banda estadounid...
# 12  1950s (pronounced nineteen-fifties; commonly a...
# 13  Sol (S/)[2]​ (ISO 4217: PEN) unidad monetaria ...
# 14  Cork (irlandés: Corcaigh, derivado corcach, ma...
# 15  prime number (or prime) natural number greater...
# 16  L'amusie anomalie psychique laquelle rythme, m...
# 17  Rain liquid water form droplets condensed atmo...
# 18  October tenth month year Julian Gregorian Cale...
# 19  Intellectual Property (alias Dark Mind - nouve...
# 20  río Platte, río Chato[1]​ original español[2]​...
# 21  n/a, escrito letras minúsculas, abreviatura us...
# 22  Thought refers ideas arrangements ideas result...
# 23  semiconductor material electrical conductivity...
# 24  denomina gas (palabra inventada científico fla...
# 25  médaille Fields prix Abel deux plus prestigieu...
# 26  sky (or celestial dome) everything lies surfac...
# 27  Solder (, North America ) fusible metal alloy ...
# 28  Tommy Pistol, né 2 juillet 1976 Queens New Yor...
# 29  Volume quantity three-dimensional space enclos...
# 30  nest structure built certain animals hold eggs...
# 31  physics vapor (American) vapour (British) subs...
# 32  The Last Ship Dernier Navire Québec série télé...
# 33  Canals human-made channels water conveyance, s...
# 34  mile English unit length linear measure equal ...
# 35  mineral sustancia natural, composición química...
# 36  Antony Charles Robert Armstrong-Jones, né 7 ma...
# 37  Quantity property exist multitude magnitude. Q...
# 38  scholarly consensus precisely constitutes reli...
# 39  Dunes población comuna francesa, región Mediod...
# 40  chairman (also chairperson, chairwoman chair) ...
# 41  Escuelas Públicas Highline (Highline Public Sc...
# 42  Meat personaje serie juegos lucha Mortal Komba...
# 43  registre Internet régional (RIR, l'anglais Reg...
# 44  L'Initiative l'Accessibilité web Web Accessibi...
# 45  côt cépage cuve noir français. également connu...
# 46  Sikorsky SH-60 / MH-60 Seahawk helicóptero nav...
# 47  Texas Tejas[2]​ cincuenta que, junto Washingto...
# 48  physics, wave oscillation accompanied transfer...
# 49  magnéto d'allumage génératrice transformant l'...

# %% [markdown]
# ## Shrink the vector space

# %%
from nltk.stem import SnowballStemmer
from nltk.stem.snowball import FrenchStemmer

stemmer_en = SnowballStemmer('english')
stemmer_fr = FrenchStemmer()
stemmer_es = SnowballStemmer('spanish')

Stemmed = []

# %%
for i in range(len(df)):
    text = df.loc[i,'Filtered'] 
    stemmed = [globals()['stemmer_'+df.loc[i,'Language']].stem(word) for word in text.split()]
    Stemmed.append(stemmed)
    print('#'*75)
    print('The word %s is in the %s language' %(df.loc[i,'Word'],df.loc[i,'Language']))
    print(*stemmed[:5], sep = '\n')
    
df['Stemmed'] = [' '.join(liste) for liste in Stemmed]
# Out:
# ###########################################################################
# The word Telephone number is in the en language
# telephon
# number
# sequenc
# digit
# assign
# ###########################################################################
# The word stencils is in the fr language
# term
# stencil,
# signif
# pochoir
# anglais,
# ###########################################################################
# The word capabilities is in the fr language
# capabl
# capac
# libert
# substantiel
# est,
# ###########################################################################
# The word diagnostics is in the en language
# diagnosi
# identif
# natur
# caus
# certain
# ###########################################################################
# The word salvages is in the en language
# savag
# island
# selvagen
# island
# (portuguese:
# ###########################################################################
# The word cleat is in the fr language
# climat
# distribu
# statist
# condit
# l'atmospher
# ###########################################################################
# The word sterilizer is in the es language
# progesterex
# nombr
# dad
# drog
# inexistent
# ###########################################################################
# The word feeling is in the fr language
# feeling
# deuxiem
# maxi-singl
# leil
# sort
# ###########################################################################
# The word mechanic is in the en language
# mechan
# tradesman,
# craftsman,
# technician
# use
# ###########################################################################
# The word official is in the fr language
# l'official
# vicair
# judiciair
# jug
# ecclésiastique.
# ###########################################################################
# The word interest is in the en language
# interest
# payment
# borrow
# deposit-tak
# financi
# ###########################################################################
# The word writing is in the es language
# automatic
# writing
# album
# debut
# band
# ###########################################################################
# The word fifties is in the en language
# 1950s
# (pronounc
# nineteen-fifties;
# common
# abbrevi
# ###########################################################################
# The word soles is in the es language
# sol
# (s/)[2]​
# (is
# 4217:
# pen)
# ###########################################################################
# The word cork is in the es language
# cork
# (irlandes:
# corcaigh,
# deriv
# corcach,
# ###########################################################################
# The word primes is in the en language
# prime
# number
# (or
# prime)
# natur
# ###########################################################################
# The word amusements is in the fr language
# l'amus
# anomal
# psychiqu
# laquel
# rythme,
# ###########################################################################
# The word rains is in the en language
# rain
# liquid
# water
# form
# droplet
# ###########################################################################
# The word octobers is in the en language
# octob
# tenth
# month
# year
# julian
# ###########################################################################
# The word property is in the fr language
# intellectual
# property
# (ali
# dark
# mind
# ###########################################################################
# The word platter is in the es language
# rio
# platte,
# rio
# chato[1]​
# original
# ###########################################################################
# The word acronyms is in the es language
# n/a,
# escrit
# letr
# minusculas,
# abreviatur
# ###########################################################################
# The word thought is in the en language
# thought
# refer
# idea
# arrang
# idea
# ###########################################################################
# The word semiconductor is in the en language
# semiconductor
# materi
# electr
# conduct
# valu
# ###########################################################################
# The word gas is in the es language
# denomin
# gas
# (palabr
# invent
# cientif
# ###########################################################################
# The word fields is in the fr language
# médaill
# field
# prix
# abel
# deux
# ###########################################################################
# The word skies is in the en language
# sky
# (or
# celesti
# dome)
# everyth
# ###########################################################################
# The word solders is in the en language
# solder
# (,
# north
# america
# )
# ###########################################################################
# The word pistol is in the fr language
# tommy
# pistol,
# né
# 2
# juillet
# ###########################################################################
# The word volume is in the en language
# volum
# quantiti
# three-dimension
# space
# enclos
# ###########################################################################
# The word nests is in the en language
# nest
# structur
# built
# certain
# anim
# ###########################################################################
# The word vapor is in the en language
# physic
# vapor
# (american)
# vapour
# (british)
# ###########################################################################
# The word ship is in the fr language
# the
# last
# ship
# derni
# navir
# ###########################################################################
# The word canals is in the en language
# canal
# human-mad
# channel
# water
# conveyance,
# ###########################################################################
# The word miles is in the en language
# mile
# english
# unit
# length
# linear
# ###########################################################################
# The word minerals is in the es language
# mineral
# sustanci
# natural,
# composicion
# quimic
# ###########################################################################
# The word stationery is in the fr language
# antony
# charl
# robert
# armstrong-jones,
# né
# ###########################################################################
# The word quantity is in the en language
# quantiti
# properti
# exist
# multitud
# magnitude.
# ###########################################################################
# The word religion is in the en language
# scholar
# consensus
# precis
# constitut
# religion.
# ###########################################################################
# The word dusts is in the es language
# dun
# poblacion
# comun
# francesa,
# region
# ###########################################################################
# The word chairwomen is in the en language
# chairman
# (also
# chairperson,
# chairwoman
# chair)
# ###########################################################################
# The word highlines is in the es language
# escuel
# public
# highlin
# (highlin
# public
# ###########################################################################
# The word meat is in the es language
# meat
# personaj
# seri
# jueg
# luch
# ###########################################################################
# The word organizations is in the fr language
# registr
# internet
# régional
# (rir,
# l'angl
# ###########################################################################
# The word guidelines is in the fr language
# l'initi
# l'accessibil
# web
# web
# accessibility
# ###########################################################################
# The word cot is in the fr language
# côt
# cépag
# cuv
# noir
# français.
# ###########################################################################
# The word lamps is in the es language
# sikorsky
# sh-60
# /
# mh-60
# seahawk
# ###########################################################################
# The word texts is in the es language
# tex
# tejas[2]​
# cincuent
# que,
# junt
# ###########################################################################
# The word wave is in the en language
# physics,
# wave
# oscil
# accompani
# transfer
# ###########################################################################
# The word magnetos is in the fr language
# magnéto
# d'allumag
# géner
# transform
# l'énerg

# %% [markdown]
# ## Cluster documents into logical groups

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
 
documents = df['Stemmed']
 

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)
 
true_k = 8
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
 
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :5]:
        print(' %s' % terms[ind])

Cluster = []

for i in range(len(df)):
    Y = vectorizer.transform([df.loc[i,'Stemmed']])
    prediction = model.predict(Y)
    Cluster.append(prediction)
    #print(df.loc[i,'Word'],prediction)

df['Cluster'] = Cluster
# Out:
# Top terms per cluster:
# Cluster 0:
#  octob
#  solder
#  island
#  metal
#  conduct
# Cluster 1:
#  may
#  mechanics
#  highlin
#  public
#  human
# Cluster 2:
#  number
#  mile
#  use
#  quantiti
#  official
# Cluster 3:
#  le
#  cet
#  mar
#  prix
#  en
# Cluster 4:
#  2007
#  personaj
#  internet
#  red
#  meat
# Cluster 5:
#  water
#  vapor
#  wave
#  liquid
#  temperatur
# Cluster 6:
#  sol
#  mineral
#  gas
#  molecul
#  sh
# Cluster 7:
#  rio
#  un
#  amus
#  sigl
#  cork
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
df.head()
# Out:
#   Language                                               Text  \
# 0       en  A telephone number is a sequence of digits ass...
# 1       fr  Le terme stencil, qui signifie « pochoir » en ...
# 2       fr  Une « capabilité » ou « capacité » ou « libert...
# 3       en  Diagnosis is the identification of the nature ...
# 4       en  The Savage Islands or Selvagens Islands (Portu...
#
#                Word                                Phone Numbers found  \
# 0  Telephone number  [555-1212, 555-1212, 776-2323, 212-736-5000, 8...
# 1          stencils                                                 []
# 2      capabilities                                                 []
# 3       diagnostics                                                 []
# 4          salvages                                                 []
#
#   Language detected  Same language ?  \
# 0                en             True
# 1                fr             True
# 2                fr             True
# 3                en             True
# 4                en             True
#
#                                         Proper Nouns  \
# 0  (PSTN) PSTN Lowell, Massachusetts, Concept Whe...
# 1                                      Le   En Selon
# 2  Une       Amartya Sen, la L’approche Martha Nu...
# 3                                          Diagnosis
# 4  Savage Selvagens Islands (Portuguese: Ilhas Se...
#
#                                             Filtered  \
# 0  telephone number sequence digits assigned fixe...
# 1  terme stencil, signifie  pochoir  anglais, pre...
# 2   capabilité   capacité   liberté substantielle...
# 3  Diagnosis identification nature cause certain ...
# 4  Savage Islands Selvagens Islands (Portuguese: ...
#
#                                              Stemmed Cluster
# 0  telephon number sequenc digit assign fixed-lin...     [2]
# 1  term stencil, signif pochoir anglais, prend di...     [2]
# 2  capabl capac libert substantiel est, suiv défi...     [3]
# 3  diagnosi identif natur caus certain phenomenon...     [2]
# 4  savag island selvagen island (portuguese: ilha...     [0]

# %%
df[df['Cluster'] == 5]
# Out:
#    Language                                               Text    Word  \
# 17       en  Rain is liquid water in the form of droplets t...   rains
# 31       en  In physics a vapor (American) or vapour (Briti...   vapor
# 33       en  Canals are human-made channels for water conve...  canals
# 48       en  In physics, a wave is an oscillation accompani...    wave
#
#    Phone Numbers found Language detected  Same language ?    Proper Nouns  \
# 17                  []                en             True     Rain Earth.
# 31                  []                en             True        A K (374
# 33                  []                en             True
# 48                  []                en             True  Frequency Wave
#
#                                              Filtered  \
# 17  Rain liquid water form droplets condensed atmo...
# 31  physics vapor (American) vapour (British) subs...
# 33  Canals human-made channels water conveyance, s...
# 48  physics, wave oscillation accompanied transfer...
#
#                                               Stemmed Cluster
# 17  rain liquid water form droplet condens atmosph...     [5]
# 31  physic vapor (american) vapour (british) subst...     [5]
# 33  canal human-mad channel water conveyance, serv...     [5]
# 48  physics, wave oscil accompani transfer energy....     [5]

# %% [markdown]
# ## Produce a basic analysis of the result

# %% [markdown]
# Interesting : the words might be random, but the KNN discovered a cluster, with different languages on top of it, that has to do with climate, environment. The words we find are skiers, canals and meat.

# %% [markdown]
# Then there's a more physics related cluster. Having words like rains, vapor, canals and wave.

# %% [markdown]
# ## Summary

# %% [markdown]
# Hard to cluster Wikipedia in different articles. Not all the climat things were in the right cluster.
#
# Since this code will each time get random words, I hope this python jupyter notebook shows the analysis on the set of Data webscrapped in the first place.
